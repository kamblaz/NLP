# %%
# %run functions.py
# Out:
# Using TensorFlow backend.

# %%
stemmer = StempelStemmer.polimorf()
# Out:
# Loading: 100%|██████████████████████████████████████████████████████| 11368252/11368252 [00:40<00:00, 532533.29bytes/s]

# %%
xall,yall = load_data_from_CSV('data.csv')
number_of_classes = 23
# Out:
# Loading: 100%|██████████████████████████████████████████████████████| 11368252/11368252 [01:27<00:00, 129613.53bytes/s]

# %%
print("Set size: ", len(xall))
# Out:
# Set size:  40085

# %%
for i in range(0,len(yall)):
    yall[i] = f(float(yall[i]))
for i in range(0,len(xall)):
    xall[i] = str(xall[i])

# %%
number_of_samples_for_each_class = count_number_of_samples_for_each_class(yall, number_of_classes)
# Out:
# 2568
# 1145
# 308
# 2020
# 313
# 2043
# 2373
# 2303
# 255
# 2463
# 241
# 2515
# 2809
# 2350
# 474
# 2546
# 892
# 484
# 1994
# 1385
# 2604
# 3000
# 3000

# %%
weights = assign_weight_for_each_class(len(yall), number_of_samples_for_each_class)

# %%
class_weight = {0: weights[0],
                1: weights[1],
                2: weights[2],
                3: weights[3],
                4: weights[4],
                5: weights[5],
                6: weights[6],
                7: weights[7],
                8: weights[8],
                9: weights[9],
                10: weights[10],
                11: weights[11],
                12: weights[12],
                13: weights[13],
                14: weights[14],
                15: weights[15],
                16: weights[16],
                17: weights[17],
                18: weights[18],
                19: weights[19],
                20: weights[20],
                21: weights[21],
                22: weights[22],
               }

# %%
yall=to_categorical(yall)

# %%
stop_words = set(stopwords.words('polish'))
processed_reviews = []
single_review = "string to iniialize <br /> my email id is charilie@waoow.com. You can also reach to me at charlie's"

for review in range(0,len(xall)):
    post_stemming = []
    single_review = xall[review]
    single_review = single_review.lower()
    single_review = re.sub('<.*?>',' ',single_review)
    single_review = re.sub('\W',' ',single_review)
    single_review = re.sub('\s+[a-zA-Z]\s+',' ', single_review)
    single_review = re.sub('\s+',' ', single_review)       
    word_tokens = word_tokenize(single_review)    
    filtered_sentence = " ".join([w for w in word_tokens if w not in stop_words])
    arr = convert(filtered_sentence)
    if(arr[0] or len(arr)>1):
        for word in arr:
            post_stemming.append(stemmer.stem(word))
    single_review = list_to_string(post_stemming)    
    processed_reviews.append(filtered_sentence)    
print(processed_reviews[0])

# %%
x_train, x_test, y_train, y_test = train_test_split(processed_reviews,yall,test_size=0.2,random_state=42)
print("Train-set size: ", len(x_train))
print("Test-set size:  ", len(x_test))
# Out:
# Train-set size:  32068
# Test-set size:   8017

# %%
data_text = x_train + x_test
num_words = 1000
tokenizer = Tokenizer(num_words=num_words)
tokenizer.fit_on_texts(data_text)
tokenizer.word_index
x_train_tokens = tokenizer.texts_to_sequences(x_train)
x_test_tokens = tokenizer.texts_to_sequences(x_test)
num_tokens = [len(tokens) for tokens in x_train_tokens + x_test_tokens]
num_tokens = np.array(num_tokens)

# %%
max_tokens = np.mean(num_tokens) + 2 * np.std(num_tokens)
max_tokens = int(max_tokens)
max_tokens
# Out:
# 39

# %%
pad = 'pre'
x_train_pad = pad_sequences(x_train_tokens, maxlen=max_tokens,
                            padding=pad, truncating=pad)

x_test_pad = pad_sequences(x_test_tokens, maxlen=max_tokens,
                           padding=pad, truncating=pad)

# %%
idx = tokenizer.word_index
inverse_map = dict(zip(idx.values(), idx.keys()))

# %%
embedding_size = 64

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(1000,64),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_size)),
    tf.keras.layers.Dense(embedding_size, activation='relu'),
    tf.keras.layers.Dense(number_of_classes, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 64)          64000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 128)               66048
# _________________________________________________________________
# dense (Dense)                (None, 64)                8256
# _________________________________________________________________
# dense_1 (Dense)              (None, 23)                1495
# =================================================================
# Total params: 139,799
# Trainable params: 139,799
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = Adam(lr=0.01)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])

# %%
# %%time
y_train=np.array(y_train)
model.fit(x_train_pad, y_train, class_weight=class_weight, validation_split=0.05, epochs=8, batch_size=number_of_classes)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 30464 samples, validate on 1604 samples
# Epoch 1/8
# 30464/30464 [==============================] - 88s 3ms/sample - loss: 2.8212 - acc: 0.1016 - val_loss: 2.7643 - val_acc: 0.1191
# Epoch 2/8
# 30464/30464 [==============================] - 74s 2ms/sample - loss: 2.6818 - acc: 0.1198 - val_loss: 2.7702 - val_acc: 0.1322
# Epoch 3/8
# 30464/30464 [==============================] - 68s 2ms/sample - loss: 2.6137 - acc: 0.1343 - val_loss: 2.7665 - val_acc: 0.1141
# Epoch 4/8
# 30464/30464 [==============================] - 78s 3ms/sample - loss: 2.5588 - acc: 0.1389 - val_loss: 2.7611 - val_acc: 0.1172
# Epoch 5/8
# 30464/30464 [==============================] - 67s 2ms/sample - loss: 2.5130 - acc: 0.1395 - val_loss: 2.8179 - val_acc: 0.1128
# Epoch 6/8
# 30464/30464 [==============================] - 84s 3ms/sample - loss: 2.4513 - acc: 0.1476 - val_loss: 2.8445 - val_acc: 0.1004
# Epoch 7/8
# 30464/30464 [==============================] - 69s 2ms/sample - loss: 2.3808 - acc: 0.1577 - val_loss: 2.9060 - val_acc: 0.1272
# Epoch 8/8
# 30464/30464 [==============================] - 72s 2ms/sample - loss: 2.3021 - acc: 0.1685 - val_loss: 3.0272 - val_acc: 0.1247
# Wall time: 10min

# %%
# %%time
y_pred = model.predict(x=x_test_pad)
# Out:
# Wall time: 5.98 s

# %%
type(model)
# Out:
# tensorflow.python.keras.engine.sequential.Sequential

# %%
model.save('my_model')
# Out:
# Loading: 100%|███████████████████████████████████████████████████████| 11368252/11368252 [13:30<00:00, 14033.24bytes/s]
# INFO:tensorflow:Assets written to: my_model\assets

# %%
model2 = keras.models.load_model('my_model')

# %%
type(model2)
# Out:
# tensorflow.python.keras.saving.saved_model.load.Sequential

# %%
y_res=[]
y_test_res=[]
##pred
for i in range(0,len(y_pred)):
    rate=classify_rate(y_pred[i])
    y_res.append(rate)

for i in range(0,len(y_test)):
    rate=np.argmax(y_test[i])
    y_test_res.append(rate)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
cm=confusion_matrix(y_test_res,y_res)
cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
import matplotlib.pyplot as plt

# %%
cm=confusion_matrix(y_test_res,y_res)
cm_display = ConfusionMatrixDisplay(cm).plot()
fig, ax = plt.subplots(figsize=(15,15))
cm_display.plot(ax=ax)

# %%
listOfTP = [0] * 25
listOfFP = [0] * 25
listOfTN = [0] * 25
listOfFN = [0] * 25

# %%
for i in range(0,len(y_test_res)):
    y_test_res[i] = g(float(y_test_res[i]))
for i in range(0,len(y_res)):
    y_res[i] = g(float(y_res[i]))

# %%
for i in range(len(listOfTP)): 
    listOfTP[i], listOfFP[i], listOfTN[i], listOfFN[i] = perf_measure(y_test_res, y_res, y_test_res[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-629cc6364a5d> in <module>()
#       1 for i in range(len(listOfTP)):
# ----> 2     listOfTP[i], listOfFP[i], listOfTN[i], listOfFN[i] = perf_measure(y_test_res, y_res, y_test_res[i])
#
# C:\Users\Kamil\Desktop\NLP\functions.py in perf_measure(y_actual, y_hat, rate)
#     143     FN = 0
#     144
# --> 145     for i in range(len(yHat)):
#     146         if y_actual[i] == y_hat[i] == rate:
#     147             TP += 1
#
# NameError: name 'yHat' is not defined

# %%
sensitivity = [0] * 25
specificity = [0] * 25
precision = [0] * 25
NPV = [0] * 25

# %%
for i in range(len(sensitivity)): 
    sensitivity[i], specificity[i], precision[i], NPV[i] = calculate_metrics(listOfTP[i], listOfFP[i], listOfTN[i], listOfFN[i])

# %%
sensitivity

# %%
specificity

# %%
precision

# %%
NPV

# %%
myset = set(y_test_res)
print(myset)

# %%
mylist = list(myset)
print (mylist)

# %%
listOfTP
